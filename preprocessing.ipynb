# %%
import pandas as pd

# %%
# df = pd.read_excel("/Users/kirtananambiar/Desktop/STAT/educationandearningsbyageandsex.xlsx", sheet_name="data",
#                     header=[0,1,2]).reset_index(drop=True)

df = pd.read_excel("/Users/kirtananambiar/Desktop/STAT/educationandearningsbyageandsex.xlsx", sheet_name="data",
                   header=None, index_col=None)

# %%
df.head()
# Out:
#                                        0  \
# 0                                  Total
# 1                                   2020
# 2  Educational attainment, year, and age
# 3                                    NaN
# 4                                    NaN
#
#                                        1                                   2  \
# 0                                    NaN                                 NaN
# 1                                    NaN                                 NaN
# 2  Number with earnings (thousands)-Male  Mean earnings Current dollars-Male
# 3                                    NaN                                 NaN
# 4                                    NaN                                 NaN
#
#                                  3                                        4  \
# 0                              NaN                                      NaN
# 1                              NaN                                      NaN
# ...

# %%
education=df.iloc[0][0]
year = df.iloc[1][0]

# %%
df= df[2:]
#df = df.dropna()

# %%
df = df.drop(df.iloc[1:3].index)


#df = df.drop(df.iloc[1:3], inplace = True)

# %%
new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header #set the header row as the df header

# %%
df['education_attainment']=education
df['year']=year

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.head(n=20)
# Out:
# 2  Educational attainment, year, and age  \
# 0                                  Total
# 1                         18 to 24 years
# 2                         25 to 34 years
# 3                         35 to 44 years
# 4                         45 to 54 years
# 5                         55 to 64 years
# 6                      65 years and over
# 11                                 Total
# 12                        18 to 24 years
# 13                        25 to 34 years
# 14                        35 to 44 years
# 15                        45 to 54 years
# 16                        55 to 64 years
# 17                     65 years and over
# 22                                 Total
# 23                        18 to 24 years
# 24                        25 to 34 years
# 25                        35 to 44 years
# 26                        45 to 54 years
# 27                        55 to 64 years
#
# 2  Number with earnings (thousands)-Male Mean earnings Current dollars-Male  \
# ...

# %%
df['Educational attainment, year, and age'] =  df['Educational attainment, year, and age'].astype(str)
 
df['Educational attainment, year, and age'] = df['Educational attainment, year, and age'].str.split('(').str[0].str.strip(' ')    

# df[df['Educational attainment, year, and age']=='.Total'] = "Total"

df.loc[df['Educational attainment, year, and age'] == ".Total","Educational attainment, year, and age"] = "Total"

# %%
import numpy as np

y = range(1990,2021)
yr=[]
for n in y:
    yr.append(str(n))

# %%
e = ['Less than 9th grade','9th to 12th grade (no diploma)','High School Graduate (includes equivalency)','Some College, No Degree','Associate Degree','Bachelor\'s Degree or More','Bachelor\'s Degree','Master\'s Degree','Professional Degree','Doctorate Degree']
    
      
for i in range(1,len(df)):
    #print(df.iloc[row]['year'])
        
    if df.loc[i,'Educational attainment, year, and age'] in yr:
           
            year = df.loc[i,'Educational attainment, year, and age']
            df.loc[i,'education_attainment'] = df.loc[i-1,'education_attainment']
            df.loc[i,'year'] = year
            #print( df.loc[i,'year'])
    elif (df.loc[i,'Educational attainment, year, and age']) in e:
            df.loc[i,'year'] = 2020
            df.loc[i,'education_attainment'] = df.loc[i,'Educational attainment, year, and age']
            
    else:
        #print(df.loc[row-1,'year'])
        df.loc[i,'year'] = df.loc[i-1,'year']
        df.loc[i,'education_attainment'] = df.loc[i-1,'education_attainment']

# %%
l = ['Total','18 to 24 years','25 to 34 years','35 to 44 years','45 to 54 years','55 to 64 years','65 years and over']
#df[df.loc['Educational attainment, year, and age'] in l]

#df[df["Educational attainment, year, and age"].str.isin(l)
   
df = df[pd.DataFrame(df['Educational attainment, year, and age'].tolist()).isin(l).any(1).values]

# %%
df.to_csv('/Users/kirtananambiar/Desktop/STAT/educationandearningsbyageandsex.csv')

# %%
df.columns
# Out:
# Index(['Educational attainment, year, and age',
#        'Number with earnings (thousands)-Male',
#        'Mean earnings Current dollars-Male', 'Mean earnings 2020 dollars-Male',
#        'Number with earnings (thousands)-Female',
#        'Mean earnings Current dollars-Female',
#        'Mean earnings 2020 dollars-Female', 'education_attainment', 'year'],
#       dtype='object', name=2)
